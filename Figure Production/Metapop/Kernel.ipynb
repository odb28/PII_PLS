# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
kernel = lambda x: 1/x**2

# %%
distances = np.arange(1,20,1)
rels = kernel(distances)

# %%
fig, ax0 = plt.subplots()
ax0.plot(distances,rels)
ax0.set_ylabel("Relative Infective Force")
ax0.set_xlabel("Distance between Nodes")
ax0.set_title("Dispersal Kernel")
fig.show()
# Out:
# C:\Users\ollie\AppData\Local\Temp\ipykernel_23368\3998027944.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
