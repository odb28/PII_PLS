# %%
import numpy as np
from src.baseSIR import model_sir
from src.baseSIR import cull_sir
import scipy as sp
import arviz as az
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
import time

# %%
N_10_b = np.genfromtxt(f"../../Data/N_10_b.csv", delimiter= ",")
N_100_b = np.genfromtxt(f"../../Data/N_100_b.csv", delimiter= ",")
N_1000_b = np.genfromtxt(f"../../Data/N_1000_b.csv", delimiter= ",")

N_10_g = np.genfromtxt(f"../../Data/N_10_g.csv", delimiter= ",")
N_100_g = np.genfromtxt(f"../../Data/N_100_g.csv", delimiter= ",")
N_1000_g = np.genfromtxt(f"../../Data/N_1000_g.csv", delimiter= ",")

# %%
seed = 1912
rng = np.random.default_rng(seed)

mu = 0
tmax = 10
tstep = 0.05
n_sim = 1000

final_sizes = pd.DataFrame(np.empty(shape=(30,2)),columns=("S","N"))
size_stds = pd.DataFrame(np.empty(shape=(30,2)),columns=("S_std","N"))
pr_ext= pd.DataFrame(np.empty(shape=(30,2)),columns=("Pr_ext","N"))
for i in range(30):
    final_s = []
    exts = []


    if i < 10:
        final_sizes.iloc[i,1] = 10
        size_stds.iloc[i,1] = 10
        pr_ext.iloc[i,1] = 10
        X0 = [9, 1, 0]
        sims = []
        for j in range(n_sim):
            s,ext = model_sir(X0,mu,beta=N_10_b[i,0],gamma=N_10_g[i,0],tmax=tmax,tstep=tstep,rng=rng)
            sims.append(s)
            if ext == 0:
                final_s.append(s*100)
            exts.append(ext)
        np.savetxt(f"../../Data/Sims_SIR/c0/Sims_{i}_c0_free_G.csv",sims,delimiter=",")

    elif 10 <= i < 20:
        final_sizes.iloc[i,1] = 100
        size_stds.iloc[i,1] = 100
        pr_ext.iloc[i,1] = 100
        X0 = [90, 10, 0]
        sims = []
        for j in range(n_sim):
            s,ext = model_sir(X0,mu,beta=N_100_b[i-10,0],gamma=N_100_g[i-10,0],tmax=tmax,tstep=tstep,rng=rng)
            sims.append(s)
            if ext == 0:
                final_s.append(s*10)
            exts.append(ext)
        np.savetxt(f"../../Data/Sims_SIR/c0/Sims_{i}_c0_free_G.csv",sims,delimiter=",")

    elif i >= 20:
        final_sizes.iloc[i,1] = 1000
        size_stds.iloc[i,1] = 1000
        pr_ext.iloc[i,1] = 1000
        X0 = [900, 100, 0]
        sims = []
        for j in range(n_sim):
            s,ext = model_sir(X0,mu,beta=N_1000_b[i-20,0],gamma=N_1000_g[i-20,0],tmax=tmax,tstep=tstep,rng=rng)
            sims.append(s)
            if ext == 0:
                final_s.append(s)
            exts.append(ext)
        np.savetxt(f"../../Data/Sims_SIR/c0/Sims_{i}_c0_free_G.csv",sims,delimiter=",")

    final_sizes.iloc[i,0] = np.mean(final_s)
    pr_ext.iloc[i,0] = sum(exts)/n_sim
    size_stds.iloc[i,0] = np.std(final_s)


np.savetxt("../../Data/Sims_SIR/Summary/Final_size_c0_free_G.csv",final_sizes,delimiter=",")
np.savetxt("../../Data/Sims_SIR/Summary/Pr_ext_c0_free_G.csv",pr_ext,delimiter=",")
np.savetxt("../../Data/Sims_SIR/Summary/Stds_c0_free_G.csv",size_stds,delimiter=",")

# %%
seed = 1912
rng = np.random.default_rng(seed)

mu = 0
tmax = 10
tstep = 0.05
n_sim = 1000
beta_mod = 0.5

final_sizes_c1 = pd.DataFrame(np.empty(shape=(30,2)),columns=("S","N"))
size_stds_c1 = pd.DataFrame(np.empty(shape=(30,2)),columns=("S_std","N"))
pr_ext_c1 = pd.DataFrame(np.empty(shape=(30,2)),columns=("Pr_ext","N"))
for i in range(30):
    final_s = []
    exts = []

    if i < 10:
        final_sizes_c1.iloc[i,1] = 10
        size_stds_c1.iloc[i,1] = 10
        pr_ext_c1.iloc[i,1] = 10
        X0 = [9, 1, 0]
        sims = []
        for j in range(n_sim):
            s,ext = model_sir(X0,mu,beta=N_10_b[i,0] * beta_mod,gamma=N_10_g[i,0],tmax=tmax,tstep=tstep,rng=rng)
            sims.append(s)
            if ext == 0:
                final_s.append(s*100)
            exts.append(ext)
        np.savetxt(f"../../Data/Sims_SIR/c1/Sims_{i}_c1_free_G.csv",sims,delimiter=",")

    elif 10 <= i < 20:
        final_sizes_c1.iloc[i,1] = 100
        size_stds_c1.iloc[i,1] = 100
        pr_ext_c1.iloc[i,1] = 100
        X0 = [90, 10, 0]
        sims = []
        for j in range(n_sim):
            s,ext = model_sir(X0,mu,beta=N_100_b[i-10,0] * beta_mod,gamma=N_100_g[i-10,0],tmax=tmax,tstep=tstep,rng=rng)
            sims.append(s)
            if ext == 0:
                final_s.append(s*10)
            exts.append(ext)
        np.savetxt(f"../../Data/Sims_SIR/c1/Sims_{i}_c1_free_G.csv",sims,delimiter=",")

    elif i >= 20:
        final_sizes_c1.iloc[i,1] = 1000
        size_stds_c1.iloc[i,1] = 1000
        pr_ext_c1.iloc[i,1] = 1000
        X0 = [900, 100, 0]
        sims = []
        for j in range(n_sim):
            s,ext = model_sir(X0,mu,beta=N_1000_b[i-20,0] * beta_mod,gamma=N_1000_g[i-20,0],tmax=tmax,tstep=tstep,rng=rng)
            sims.append(s)
            if ext == 0:
                final_s.append(s)
            exts.append(ext)
        np.savetxt(f"../../Data/Sims_SIR/c1/Sims_{i}_c1_free_G.csv",sims,delimiter=",")

    final_sizes_c1.iloc[i,0] = np.mean(final_s)
    pr_ext_c1.iloc[i,0] = sum(exts)/n_sim
    size_stds_c1.iloc[i,0] = np.std(final_s)
np.savetxt("../../Data/Sims_SIR/Summary/Final_size_c1_free_G.csv",final_sizes_c1,delimiter=",")
np.savetxt("../../Data/Sims_SIR/Summary/Pr_ext_c1_free_G.csv",pr_ext_c1,delimiter=",")
np.savetxt("../../Data/Sims_SIR/Summary/Stds_c1_free_G.csv",size_stds_c1,delimiter=",")

# %%
seed = 1912
rng = np.random.default_rng(seed)

mu = 0
tmax = 10
tstep = 0.05
n_sim = 1000

omega = 1

final_sizes_c2 = pd.DataFrame(np.empty(shape=(30,2)),columns=("S","N"))
size_stds_c2 = pd.DataFrame(np.empty(shape=(30,2)),columns=("S_std","N"))
pr_ext_c2 = pd.DataFrame(np.empty(shape=(30,2)),columns=("Pr_ext","N"))
for i in range(30):
    final_s = []
    exts = []

    if i < 10:
        final_sizes_c2.iloc[i,1] = 10
        size_stds_c2.iloc[i,1] = 10
        pr_ext_c2.iloc[i,1] = 10
        X0 = [9, 1, 0]
        sims = []
        for j in range(n_sim):
            s,ext = model_sir(X0,mu,beta=N_10_b[i,0],gamma=N_10_g[i,0] + omega,tmax=tmax,tstep=tstep,rng=rng)
            sims.append(s)
            if ext == 0:
                final_s.append(s*100)
            exts.append(ext)
        np.savetxt(f"../../Data/Sims_SIR/c2/Sims_{i}_c2_free_G.csv",sims,delimiter=",")

    elif 10 <= i < 20:
        final_sizes_c2.iloc[i,1] = 100
        size_stds_c2.iloc[i,1] = 100
        pr_ext_c2.iloc[i,1] = 100
        X0 = [90, 10, 0]
        sims = []
        for j in range(n_sim):
            s,ext = model_sir(X0,mu,beta=N_100_b[i-10,0],gamma=N_100_g[i-10,0]+ omega,tmax=tmax,tstep=tstep,rng=rng)
            sims.append(s)
            if ext == 0:
                final_s.append(s*10)
            exts.append(ext)
        np.savetxt(f"../../Data/Sims_SIR/c2/Sims_{i}_c2_free_G.csv",sims,delimiter=",")

    elif i >= 20:
        final_sizes_c2.iloc[i,1] = 1000
        size_stds_c2.iloc[i,1] = 1000
        pr_ext_c2.iloc[i,1] = 1000
        X0 = [900, 100, 0]
        sims = []
        for j in range(n_sim):
            s,ext = model_sir(X0,mu,beta=N_1000_b[i-20,0],gamma=N_1000_g[i-20,0]+ omega,tmax=tmax,tstep=tstep,rng=rng)
            if ext == 0:
                final_s.append(s)
            exts.append(ext)
        np.savetxt(f"../../Data/Sims_SIR/c2/Sims_{i}_c2_free_G.csv",sims,delimiter=",")

    final_sizes_c2.iloc[i,0] = np.mean(final_s)
    pr_ext_c2.iloc[i,0] = sum(exts)/n_sim
    size_stds_c2.iloc[i,0] = np.std(final_s)
np.savetxt("../../Data/Sims_SIR/Summary/Final_size_c2_free_G.csv",final_sizes_c2,delimiter=",")
np.savetxt("../../Data/Sims_SIR/Summary/Pr_ext_c2_free_G.csv",pr_ext_c2,delimiter=",")
np.savetxt("../../Data/Sims_SIR/Summary/Stds_c2_free_G.csv",size_stds_c2,delimiter=",")

# %%
seed = 1912
rng = np.random.default_rng(seed)
from src.baseSIR import cull_sir
mu = 0
tmax = 10
tstep = 0.05
n_sim = 1000


final_sizes_c3 = pd.DataFrame(np.empty(shape=(30,2)),columns=("S","N"))
size_stds_c3 = pd.DataFrame(np.empty(shape=(30,2)),columns=("S_std","N"))
pr_ext_c3 = pd.DataFrame(np.empty(shape=(30,2)),columns=("Pr_ext","N"))
for i in range(30):
    final_s = []
    exts = []

    if i < 10:
        final_sizes_c3.iloc[i,1] = 10
        size_stds_c3.iloc[i,1] = 10
        pr_ext_c3.iloc[i,1] = 10
        X0 = [9, 1, 0]
        sims = []
        for j in range(n_sim):
            s,ext = cull_sir(X0,mu,beta=N_10_b[i,0],gamma=N_10_g[i,0],tmax=tmax,tstep=tstep,rng=rng)
            sims.append(s)
            if ext == 0:
                final_s.append(s*100)
            exts.append(ext)
        np.savetxt(f"../../Data/Sims_SIR/c3/Sims_{i}_c3_free_G.csv",sims,delimiter=",")

    elif 10 <= i < 20:
        final_sizes_c3.iloc[i,1] = 100
        size_stds_c3.iloc[i,1] = 100
        pr_ext_c3.iloc[i,1] = 100
        X0 = [90, 10, 0]
        sims = []
        for j in range(n_sim):
            s,ext = cull_sir(X0,mu,beta=N_100_b[i-10,0],gamma=N_100_g[i-10,0],tmax=tmax,tstep=tstep,rng=rng)
            sims.append(s)
            if ext == 0:
                final_s.append(s*10)
            exts.append(ext)
        np.savetxt(f"../../Data/Sims_SIR/c3/Sims_{i}_c3_free_G.csv",sims,delimiter=",")

    elif i >= 20:
        final_sizes_c3.iloc[i,1] = 1000
        size_stds_c3.iloc[i,1] = 1000
        pr_ext_c3.iloc[i,1] = 1000
        X0 = [900, 100, 0]
        sims = []
        for j in range(n_sim):
            s,ext = cull_sir(X0,mu,beta=N_1000_b[i-20,0],gamma=N_1000_g[i-20,0],tmax=tmax,tstep=tstep,rng=rng)
            sims.append(s)
            if ext == 0:
                final_s.append(s)
            exts.append(ext)
        np.savetxt(f"../../Data/Sims_SIR/c3/Sims_{i}_c3_free_G.csv",sims,delimiter=",")

    final_sizes_c3.iloc[i,0] = np.mean(final_s)
    pr_ext_c3.iloc[i,0] = sum(exts)/n_sim
    size_stds_c3.iloc[i,0] = np.std(final_s)
np.savetxt("../../Data/Sims_SIR/Summary/Final_size_c3_free_G.csv",final_sizes_c3,delimiter=",")
np.savetxt("../../Data/Sims_SIR/Summary/Pr_ext_c3_free_G.csv",pr_ext_c3,delimiter=",")
np.savetxt("../../Data/Sims_SIR/Summary/Stds_c3_free_G.csv",size_stds_c3,delimiter=",")
