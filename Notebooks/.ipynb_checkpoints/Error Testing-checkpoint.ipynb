# %%
import time
import numpy as np
import pymc as pm
from src.baseSIR import real_sir
import arviz as az



#Initialise RNG
seed = 6
rng = np.random.default_rng(seed)
def sim_sir(model_rng, b, g, size=None):
    return real_sir(X0, mu, b, g, tmax, tstep, rng) * factor


# Run the "real world"
X0 = [900, 100, 0]
beta = 3
gamma = 1
mu = 0
tmax = 10
tstep = 0.05
start_time = time.time()
reality = real_sir(X0, mu, beta, gamma, tmax, tstep,rng)
print(f"Reality took {time.time() - start_time} seconds to run!")
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Reality took 0.02724146842956543 seconds to run!

# %%
# Resolution X1
X0 = [900, 100, 0]
mu = 0
tmax = 10
tstep = 0.05
factor = 1
start_time = time.time()
with pm.Model() as test:
    b = pm.HalfNormal("b", 5)
    g = pm.HalfNormal("g", 5)
    s = pm.Simulator("s", sim_sir, params=(b, g), epsilon=500, observed=reality)
    idata1 = pm.sample_smc(progressbar=False)
print(f"Resolution X1 took {time.time() - start_time} seconds to fit!")
# Out:
# Initializing SMC sampler...
# Sampling 6 chains in 6 jobs
# C:\Users\ollie\anaconda3\envs\PLS Research\lib\site-packages\arviz\data\base.py:221: UserWarning: More chains (6) than draws (5). Passed array should have shape (chains, draws, *shape)
#   warnings.warn(
# Resolution X1 took 1762.7855622768402 seconds to fit!

# %%
idata1.sample_stats
# Out:
# <xarray.Dataset>
# Dimensions:                  (chain: 6, draw: 5)
# Coordinates:
#   * chain                    (chain) int32 0 1 2 3 4 5
#   * draw                     (draw) int32 0 1 2 3 4
# Data variables:
#     log_marginal_likelihood  (chain, draw) object nan nan nan ... nan nan -5.461
#     beta                     (chain, draw) object 0.0086822509765625 ... 1
#     accept_rate              (chain, draw) object 0.7307 0.7133 ... 0.7111 0.675
# Attributes:
#     created_at:                 2023-11-06T19:56:03.322614
#     arviz_version:              0.16.0
#     inference_library:          pymc
#     inference_library_version:  5.6.1
#     _n_draws:                   2000
#     threshold:                  0.5
#     _n_tune:                    6
#     correlation_threshold:      0.01
#     _t_sampling:                1760.6023988723755

# %%
# Resolution X10
X0 = [90, 10, 0]
mu = 0
tmax = 10
tstep = 0.05
factor = 10
start_time = time.time()
with pm.Model() as test:
    b = pm.HalfNormal("b", 5)
    g = pm.HalfNormal("g", 5)
    s = pm.Simulator("s", sim_sir, params=(b, g), epsilon=500, observed=reality)
    idata2 = pm.sample_smc(progressbar=False)
print(f"Resolution X2 took {time.time() - start_time} seconds to fit!")
# Out:
# Initializing SMC sampler...
# Sampling 6 chains in 6 jobs
# C:\Users\ollie\anaconda3\envs\PLS Research\lib\site-packages\arviz\data\base.py:221: UserWarning: More chains (6) than draws (5). Passed array should have shape (chains, draws, *shape)
#   warnings.warn(
# Resolution X2 took 381.9401249885559 seconds to fit!

# %%
y = idata2.sample_stats
np.savetxt("../Data/Error_6_N_100.csv",y,delimiter=",")
# Out:
# <xarray.Dataset>
# Dimensions:                  (chain: 6, draw: 5)
# Coordinates:
#   * chain                    (chain) int32 0 1 2 3 4 5
#   * draw                     (draw) int32 0 1 2 3 4
# Data variables:
#     log_marginal_likelihood  (chain, draw) object nan nan nan ... nan nan -6.011
#     beta                     (chain, draw) object 0.008148193359375 ... 1
#     accept_rate              (chain, draw) object 0.6969 0.651 ... 0.3578 0.2881
# Attributes:
#     created_at:                 2023-11-06T20:02:25.951480
#     arviz_version:              0.16.0
#     inference_library:          pymc
#     inference_library_version:  5.6.1
#     _n_draws:                   2000
#     threshold:                  0.5
#     _n_tune:                    11
#     correlation_threshold:      0.01
#     _t_sampling:                381.6312663555145

# %%
# Resolution X100
X0 = [9, 1, 0]
mu = 0
tmax = 10
tstep = 0.05
factor = 100
start_time = time.time()
with pm.Model() as test:
    b = pm.HalfNormal("b", 5)
    g = pm.HalfNormal("g", 5)
    s = pm.Simulator("s", sim_sir, params=(b, g), epsilon=500, observed=reality)
    idata3 = pm.sample_smc(progressbar=False)
print(f"Resolution X3 took {time.time() - start_time} seconds to fit!")
# Out:
# Initializing SMC sampler...
# Sampling 6 chains in 6 jobs
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# Resolution X3 took 138.7192497253418 seconds to fit!

# %%
idata3.sample_stats
# Out:
# <xarray.Dataset>
# Dimensions:                  (chain: 6, draw: 6)
# Coordinates:
#   * chain                    (chain) int32 0 1 2 3 4 5
#   * draw                     (draw) int32 0 1 2 3 4 5
# Data variables:
#     log_marginal_likelihood  (chain, draw) object nan nan nan ... nan nan -10.38
#     beta                     (chain, draw) object 0.00533294677734375 ... 1
#     accept_rate              (chain, draw) object 0.5081 0.3893 ... 0.03 0.02017
# Attributes:
#     created_at:                 2023-11-06T20:04:44.736443
#     arviz_version:              0.16.0
#     inference_library:          pymc
#     inference_library_version:  5.6.1
#     _n_draws:                   2000
#     threshold:                  0.5
#     _n_tune:                    8
#     correlation_threshold:      0.01
#     _t_sampling:                138.47144651412964
